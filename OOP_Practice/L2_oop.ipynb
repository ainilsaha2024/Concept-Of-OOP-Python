# %% [markdown]
# # OOP Basics | In depth Session | Bangla

# %%
class student : # class definition 
    def __init__(self): # constructor 
        print("An object is created")

s1= student( ) # 1st object creation done 
s2= student( ) # 2nd object creation done
# Out:
# An object is created
# An object is created

# %%
print(s1) # s1 is the object of class student and it is location in memory

# %%
print(s2)
# s2 is the object of class student and it is location in memory
# not same location as s1

# %%
class info: # class definition | design | blueprint 
    def __init__ (self,nm,age):
        name = nm # instance variable
        Age = age # instance variable 
        print(name,Age)

x = info("John", 25) # 1st objact creation 
y = info("thomas",30) # 2nd objact creation
# Out:
# John 25
# thomas 30
